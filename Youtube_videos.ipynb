# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\priya'

# %%
import pandas as pd

# %%
data1 = pd.read_csv("CAvideos.csv")
data1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
import json
with open("CA_category_id.json") as json_file:
         data = json.load(json_file)
        
print(data)
type(data)
# Out:
# {'kind': 'youtube#videoCategoryListResponse', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"', 'items': [{'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"', 'id': '1', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Film & Animation', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"', 'id': '2', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Autos & Vehicles', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"', 'id': '10', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Music', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"', 'id': '15', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Pets & Animals', 'assignable': True}}, {'kind': 'yo
# ...

# %%
with open("CA_category_id.json") as json_file:
         data = json.load(json_file)
        
print(data)
type(data)
# Out:
# {'kind': 'youtube#videoCategoryListResponse', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"', 'items': [{'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"', 'id': '1', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Film & Animation', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"', 'id': '2', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Autos & Vehicles', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"', 'id': '10', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Music', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"', 'id': '15', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Pets & Animals', 'assignable': True}}, {'kind': 'yo
# ...

# %%
df = pd.Series(data, index = ['kind', 'etag', 'items'])

# %%
df.head()
# Out:
# kind                     youtube#videoCategoryListResponse
# etag     "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# items    [{'kind': 'youtube#videoCategory', 'etag': '"l...
# dtype: object

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df4 = df['items']

# %%
type(df4)
# Out:
# list

# %%
print(df4)
# Out:
# [{'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"', 'id': '1', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Film & Animation', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"', 'id': '2', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Autos & Vehicles', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"', 'id': '10', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Music', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"', 'id': '15', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Pets & Animals', 'assignable': True}}, {'kind': 'youtube#videoCategory', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM1XVQ9zbGec"', 'id': '17', 'snippet': {'channelI
# ...

# %%
type(df4)
# Out:
# list

# %%
df5 = pd.DataFrame.from_records(df4)

# %%
print(df5)
# Out:
#                                                  etag  id  \
# 0   "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...   1
# 1   "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...   2
# 2   "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...  10
# 3   "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...  15
# 4   "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...  17
# 5   "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...  18
# 6   "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...  19
# 7   "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...  20
# 8   "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...  21
# 9   "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...  22
# 10  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...  23
# 11  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UVB9oxX2Bvqa_w_y3...  24
# 12  "ld9biNPKjAjgjV7EZ4EKeEGrhao/QiLK0ZIrFoORdk_g2...  25
# 13  "ld9biNPKjAjgjV7EZ4EKeEGrhao/r6Ck6Z0_L0rG37VJQ...  26
# 14  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EoYkczo9I3RCf96Rv...  27
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df_id = df5.iloc[:,[0,1,2]]
df_id.head()
type(df_id)
# Out:
# pandas.core.frame.DataFrame

# %%
df_snippet = df5["snippet"]
df_snippet.head()
# Out:
# 0    {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 1    {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 2    {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 3    {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 4    {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# Name: snippet, dtype: object

# %%
type(df_snippet)
# Out:
# pandas.core.series.Series

# %%
df6 = pd.DataFrame.from_records(df_snippet)

# %%
print(df6)
# Out:
#     assignable                 channelId                 title
# 0         True  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation
# 1         True  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles
# 2         True  UCBR8-60-B28hp2BmDPdntcQ                 Music
# 3         True  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals
# 4         True  UCBR8-60-B28hp2BmDPdntcQ                Sports
# 5        False  UCBR8-60-B28hp2BmDPdntcQ          Short Movies
# 6         True  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events
# 7         True  UCBR8-60-B28hp2BmDPdntcQ                Gaming
# 8        False  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging
# 9         True  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs
# 10        True  UCBR8-60-B28hp2BmDPdntcQ                Comedy
# 11        True  UCBR8-60-B28hp2BmDPdntcQ         Entertainment
# 12        True  UCBR8-60-B28hp2BmDPdntcQ       News & Politics
# 13        True  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style
# ...

# %%
final_df = pd.concat([df_id,df6], axis = 1, sort = False)

# %%
final_df.head()
# Out:
#                                                 etag  id  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...   1
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...   2
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...  10
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...  15
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...  17
#
#                     kind  assignable                 channelId  \
# 0  youtube#videoCategory        True  UCBR8-60-B28hp2BmDPdntcQ
# 1  youtube#videoCategory        True  UCBR8-60-B28hp2BmDPdntcQ
# 2  youtube#videoCategory        True  UCBR8-60-B28hp2BmDPdntcQ
# 3  youtube#videoCategory        True  UCBR8-60-B28hp2BmDPdntcQ
# 4  youtube#videoCategory        True  UCBR8-60-B28hp2BmDPdntcQ
#
#               title
# 0  Film & Animation
# 1  Autos & Vehicles
# 2             Music
# 3    Pets & Animals
# 4            Sports

# %%
final_df.dtypes
# Out:
# etag          object
# id            object
# kind          object
# assignable      bool
# channelId     object
# title         object
# dtype: object

# %%
final_df.id = final_df.id.astype(int)

# %%
final_df.dtypes
# Out:
# etag          object
# id             int32
# kind          object
# assignable      bool
# channelId     object
# title         object
# dtype: object

# %%
data1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
data1.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
data1.rename(columns = {'category_id' : 'id'}, inplace = True)

# %%
data1.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# id                         int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df_final1 = pd.merge(data1, final_df, on = "id")

# %%
df_final1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  2Vv-BfVoq4g      17.14.11
# 2  H1KBHFXm2Bg      17.14.11
# 3  7MxiQ4v0EnE      17.14.11
# 4  j67FgNEvyh8      17.14.11
#
#                                              title_x  channel_title  id  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé     EminemVEVO  10
# 1        Ed Sheeran - Perfect (Official Music Video)     Ed Sheeran  10
# 2    21 Savage - Bank Account (Official Music Video)      21 Savage  10
# 3  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...  Speed Records  10
# 4  Telefoon || Babbu Maan || Promo || Full Song 1...       Hey Yolo  10
#
#                publish_time  \
# 0  2017-11-10T17:00:03.000Z
# 1  2017-11-09T11:04:14.000Z
# 2  2017-11-10T19:00:02.000Z
# 3  2017-11-11T16:41:15.000Z
# 4  2017-11-12T04:24:34.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# ...

# %%
df_final1.dtypes
# Out:
# video_id                  object
# trending_date             object
# title_x                   object
# channel_title             object
# id                         int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# etag                      object
# kind                      object
# assignable                  bool
# channelId                 object
# title_y                   object
# dtype: object

# %%
df_final1['trending_date'] = pd.to_datetime(df_final1['trending_date'].str.strip(), format = '%y.%d.%m')

# %%
df_final1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc    2017-11-14
# 1  2Vv-BfVoq4g    2017-11-14
# 2  H1KBHFXm2Bg    2017-11-14
# 3  7MxiQ4v0EnE    2017-11-14
# 4  j67FgNEvyh8    2017-11-14
#
#                                              title_x  channel_title  id  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé     EminemVEVO  10
# 1        Ed Sheeran - Perfect (Official Music Video)     Ed Sheeran  10
# 2    21 Savage - Bank Account (Official Music Video)      21 Savage  10
# 3  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...  Speed Records  10
# 4  Telefoon || Babbu Maan || Promo || Full Song 1...       Hey Yolo  10
#
#                publish_time  \
# 0  2017-11-10T17:00:03.000Z
# 1  2017-11-09T11:04:14.000Z
# 2  2017-11-10T19:00:02.000Z
# 3  2017-11-11T16:41:15.000Z
# 4  2017-11-12T04:24:34.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# ...

# %%
df_final1.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title_x                           object
# channel_title                     object
# id                                 int64
# publish_time                      object
# tags                              object
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description                       object
# etag                              object
# kind                              object
# assignable                          bool
# channelId                         object
# title_y                           object
# dtype: object

# %%
df_final1.head(2)
# Out:
#       video_id trending_date                                      title_x  \
# 0  n1WpP7iowLc    2017-11-14   Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  2Vv-BfVoq4g    2017-11-14  Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title  id              publish_time  \
# 0    EminemVEVO  10  2017-11-10T17:00:03.000Z
# 1    Ed Sheeran  10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  ...                                  thumbnail_link  \
# 0     43420  ...  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1     21082  ...  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   comments_disabled  ratings_disabled  video_error_or_removed  \
# 0             False             False                   False
# ...

# %%
df_final1['month'] = df_final1['trending_date'].dt.month

# %%
df_final1['year'] = df_final1['trending_date'].dt.year

# %%
df_final1['year'].unique()
# Out:
# array([2017, 2018], dtype=int64)

# %%
df_final1['month'].unique()
# Out:
# array([11, 12,  1,  2,  3,  4,  5,  6], dtype=int64)

# %%
df_final1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc    2017-11-14
# 1  2Vv-BfVoq4g    2017-11-14
# 2  H1KBHFXm2Bg    2017-11-14
# 3  7MxiQ4v0EnE    2017-11-14
# 4  j67FgNEvyh8    2017-11-14
#
#                                              title_x  channel_title  id  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé     EminemVEVO  10
# 1        Ed Sheeran - Perfect (Official Music Video)     Ed Sheeran  10
# 2    21 Savage - Bank Account (Official Music Video)      21 Savage  10
# 3  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...  Speed Records  10
# 4  Telefoon || Babbu Maan || Promo || Full Song 1...       Hey Yolo  10
#
#                publish_time  \
# 0  2017-11-10T17:00:03.000Z
# 1  2017-11-09T11:04:14.000Z
# 2  2017-11-10T19:00:02.000Z
# 3  2017-11-11T16:41:15.000Z
# 4  2017-11-12T04:24:34.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# ...

# %%
df_new = df_final1[["trending_date","title_x","channel_title","id","tags","views","likes","dislikes","title_y","month","year"]]

# %%
df_new.head()
# Out:
#   trending_date                                            title_x  \
# 0    2017-11-14         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1    2017-11-14        Ed Sheeran - Perfect (Official Music Video)
# 2    2017-11-14    21 Savage - Bank Account (Official Music Video)
# 3    2017-11-14  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...
# 4    2017-11-14  Telefoon || Babbu Maan || Promo || Full Song 1...
#
#    channel_title  id                                               tags  \
# 0     EminemVEVO  10  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 1     Ed Sheeran  10  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# 2      21 Savage  10  21 savage|"bank account"|"21 savage bank accou...
# 3  Speed Records  10  punjabi songs|"punjabi bhangra"|"punjabi music...
# 4       Hey Yolo  10  Telefoon|"Babbu Maan"|"Mehfil Mitran Di"|"new ...
#
#       views    likes  dislikes title_y  month  year
# 0  17158579   787425     43420   Music     11  2017
# ...

# %%
export_csv = df_new.to_csv (r'youtubeNew.csv', index = None, header=True)

# %%
df_tags = df_new[["id", "title_y","tags"]]

# %%
df_tags.head()
# Out:
#    id title_y                                               tags
# 0  10   Music  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 1  10   Music  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# 2  10   Music  21 savage|"bank account"|"21 savage bank accou...
# 3  10   Music  punjabi songs|"punjabi bhangra"|"punjabi music...
# 4  10   Music  Telefoon|"Babbu Maan"|"Mehfil Mitran Di"|"new ...

# %%
df_tags["id"].unique()
# Out:
# array([10, 23, 24, 25, 22, 26,  1, 28, 20, 17, 15, 19,  2, 27, 43, 30],
#       dtype=int64)

# %%
import numpy as np
df_tags[['id','tags']].describe(include = np.object).transpose()
# Out:
#       count unique     top  freq
# tags  40807  20123  [none]  2379

# %%
df_1 = df_tags.groupby('id')

# %% [markdown]
# df_1.head()

# %%
df_1.head()
# Out:
#        id           title_y                                               tags
# 0      10             Music  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 1      10             Music  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# 2      10             Music  21 savage|"bank account"|"21 savage bank accou...
# 3      10             Music  punjabi songs|"punjabi bhangra"|"punjabi music...
# 4      10             Music  Telefoon|"Babbu Maan"|"Mehfil Mitran Di"|"new ...
# 3731   23            Comedy  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...
# 3732   23            Comedy  racist superman|"rudy"|"mancuso"|"king"|"bach"...
# 3733   23            Comedy  Funny Moments|"Montage video games"|"gaming"|"...
# 3734   23            Comedy      prank|"pranks"|"nelk"|"nelkfilmz"|"nelkfilms"
# 3735   23            Comedy  danny duncan|"danny duncan 69"|"kevin"|"danny ...
# 7504   24     Entertainment  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
# ...

# %%
type(df_1)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_1 = df_1.apply(lambda x : x)

# %%
df_1.head()
# Out:
#    id title_y           tags
# 0  10   Music         Eminem
# 1  10   Music      edsheeran
# 2  10   Music      21 savage
# 3  10   Music  punjabi songs
# 4  10   Music       Telefoon

# %%
type(df_1)
#df_1.apply(lambda x : x)
newdf = pd.DataFrame(df_1.tags.str.split('|').tolist(), index = df_1.id).stack()

# %%
newdf.head()
# Out:
# id
# 10  0           Eminem
#     0        edsheeran
#     0        21 savage
#     0    punjabi songs
#     0         Telefoon
# dtype: object

# %%
newdf = newdf.reset_index([0,"id"])

# %%
newdf.head()
# Out:
#    id              0
# 0  10         Eminem
# 1  10      edsheeran
# 2  10      21 savage
# 3  10  punjabi songs
# 4  10       Telefoon

# %%
newdf.dropna()
# Out:
#        id                                                  0
# 0      10                                             Eminem
# 1      10                                          edsheeran
# 2      10                                          21 savage
# 3      10                                      punjabi songs
# 4      10                                           Telefoon
# 5      10                          Ek Dil Ek Jaan Video Song
# 6      10                                               Koke
# 7      10                           Jennifer Lopez ft. Wisin
# 8      10                                                nav
# 9      10                                        MEET HUNDAL
# 10     10                                              Drako
# 11     10                                             donnie
# 12     10                                             Davido
# 13     10                                BPG/RVG/RCA Records
# ...

# %%
newdf1 = newdf.groupby("id")

# %% [markdown]
# newdf1.head()

# %%
newdf1.head(45)
# Out:
#        id                                                  0
# 0      10                                             Eminem
# 1      10                                          edsheeran
# 2      10                                          21 savage
# 3      10                                      punjabi songs
# 4      10                                           Telefoon
# 5      10                          Ek Dil Ek Jaan Video Song
# 6      10                                               Koke
# 7      10                           Jennifer Lopez ft. Wisin
# 8      10                                                nav
# 9      10                                        MEET HUNDAL
# 10     10                                              Drako
# 11     10                                             donnie
# 12     10                                             Davido
# 13     10                                BPG/RVG/RCA Records
# ...

# %%
newdf2 = newdf1[0].value_counts()

# %%
print(newdf2)
newdf2.columns
# Out:
#                                      0
# id 0
# 1  [none]                          117
#    電視劇                             116
#    Rooster Teeth                   101
#    screenjunkies                    56
#    Trailer                          49
#    Cinema                           37
#    琅琊榜之风起长林                         32
#    jaiden                           27
#    its alex clark                   24
#    horror                           23
#    Pixar                            22
#    leroy                            22
#    Lucas the Spider                 20
#    Disney                           16
#    Senselet                         15
#    结爱·千岁大人的初恋                       15
#    Anime Zone                       14
#    Goldmines Movies                 14
#    LucastheSpider                   14
#    Yasmine Amari                    14
#    南方有乔木                            14
#    HBO                              13
#    Movie Review                     13
# ...

# %%
export_csv1 = newdf2.to_csv (r'youtubeNew1.csv', index = None, header=True)

# %%
type(newdf2)
# Out:
# pandas.core.series.Series

# %%
newdf2 = pd.DataFrame(newdf2)

# %%
type(newdf2)
# Out:
# pandas.core.frame.DataFrame

# %%
tags_count = df_tags.groupby('title_y').agg({'tags' : pd.Series.count}).rename(columns = {'title_y' : 'category','tags' : 'count_tags'})

# %%
tags_count.head()
# Out:
#                   count_tags
# title_y
# Autos & Vehicles         353
# Comedy                  3773
# Education                991
# Entertainment          13451
# Film & Animation        2060

# %%
tags_count.sort_values('count_tags', ascending = False)
# Out:
#                       count_tags
# title_y
# Entertainment              13451
# News & Politics             4159
# People & Blogs              4105
# Comedy                      3773
# Music                       3731
# Sports                      2787
# Film & Animation            2060
# Howto & Style               2007
# Gaming                      1344
# Science & Technology        1155
# Education                    991
# Travel & Events              392
# Pets & Animals               369
# Autos & Vehicles             353
# Shows                        124
# Movies                         6

# %%
from nltk.tokenize import word_tokenize
df1 = df_tags[["tags"]]
df1.head()
df2 = df_tags.tags.str.split("|").str[0]
#tokenized_text = word__tokenize(df_tags[["tags"]])

# %%
print(df2)
# Out:
# 0                                                   Eminem
# 1                                                edsheeran
# 2                                                21 savage
# 3                                            punjabi songs
# 4                                                 Telefoon
# 5                                Ek Dil Ek Jaan Video Song
# 6                                                     Koke
# 7                                 Jennifer Lopez ft. Wisin
# 8                                                      nav
# 9                                              MEET HUNDAL
# 10                                                   Drako
# 11                                                  donnie
# 12                                                  Davido
# 13                                     BPG/RVG/RCA Records
# 14                                                  [none]
# 15                                              Gucci Mane
# ...

# %%
df2_token.head()
# Out:
# 0            [Eminem]
# 1         [edsheeran]
# 2        [21, savage]
# 3    [punjabi, songs]
# 4          [Telefoon]
# Name: 0, dtype: object

# %%
df2_token = pd.DataFrame(df2_token)

# %%
type(df2_token)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df2_token.columns.values)
# Out:
# [0]
